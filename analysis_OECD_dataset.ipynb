# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
datasetfolder = './downloaded_data/8'

# %%
numFolds = os.listdir(datasetfolder)

# %%
for fold in numFolds:
    print(fold)
# Out:
# 0
# 1
# 2

# %%
with open(os.path.join(datasetfolder,'0.html'),'r', encoding = 'utf-8') as file:
    html_doc = file.read()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_doc, 'lxml')

# %%
mydivs = soup.find("div", {"id": "SubstanceName"})

# %%
mydivs.h1.text #title
# Out:
# 'Hyoscine'

# %%
alldata = soup.find("div", {"id": "SectionContent"})

# %%
identification_title = alldata.find("h3", {"id": "sIdentification"})
identification_title.text
# Out:
# 'Identification'

# %%
identification_section = alldata.find("div", {"class": "sBlock"})

# %%
img = identification_section.div.div.img['src']
img = img[0:-1]

# %%
img
# Out:
# 'data:image/png;base64,...'

# %%
test = 'data:image/png;base64,...'

# %%
from PIL import Image
from io import BytesIO
import re, time, base64
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

def getI420FromBase64(codec, image_path="."):
    base64_data = re.sub('^data:image/.+;base64,', '', codec)
    byte_data = base64.b64decode(base64_data+'==')
    image_data = BytesIO(byte_data)
    img = Image.open(image_data)
    #img.save(image_path + '.png', "PNG")
    return img

# %%
imgdata = base64.b64decode(str(test),'utf-8')
image = Image.open(io.BytesIO(imgdata))
im = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-119-07eb4dad482a> in <module>
# ----> 1 imgdata = base64.b64decode(str(test),'utf-8')
#       2 image = Image.open(io.BytesIO(imgdata))
#       3 im = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)
#
# ~\Anaconda3\lib\base64.py in b64decode(s, altchars, validate)
#      81     if altchars is not None:
#      82         altchars = _bytes_from_decode_data(altchars)
# ---> 83         assert len(altchars) == 2, repr(altchars)
#      84         s = s.translate(bytes.maketrans(altchars, b'+/'))
#      85     if validate and not re.match(b'^[A-Za-z0-9+/]*={0,2}$', s):
#
# AssertionError: b'utf-8'

# %%
#codec = 'data:image/png;base64,...'

t = getI420FromBase64(test)

# %%
t
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x350 at 0x226D8D8A978>

# %%
class oecd_struct:
    def __init__(self,htmlfile):
        
        with open(htmlfile,'r', encoding = 'utf-8') as file:
            html_doc = file.read()
        self.soup = BeautifulSoup(html_doc, 'lxml')
        self.allsections = self.soup.find("div", {"id": "SectionContent"})
    
    def title(self):
        titlediv = soup.find("div", {"id": "SubstanceName"})
        return titlediv.h1.text
    
    def identification_block(self):
        block_data = {}
        #first sBlock div is identification table
        identification_section = self.allsections.find("div", {"class": "sBlock"})
        image = identification_section.div.find("div", {"class": "col-xs-3"}).img['src']
        block_data['image'] = image
        
        identification_table = self.identification_section.find("div", {"class": "col-xs-9"})

# %%
tab = identification_section.find("div", {"class": "col-xs-9"}).dl
tab
# Out:
# <dl class="HorDL"> <dt>Display Name:</dt> <a href="/registration-dossier/-/registered-dossier/20490/11/?documentUUID=678a638f-c7c7-4b6a-ae29-b20930206f81"> <dd> Hyoscine </dd> </a> <dt>EC Number:</dt> <dd>200-090-3</dd> <dt>EC Name:</dt> <dd>Hyoscine</dd> <dt>CAS Number:</dt> <dd> 51-34-3 </dd> <dt>Molecular formula:</dt> <dd> C17H21NO4 </dd> <dt>IUPAC Name:</dt> <dd> (1R,2R,4S,5S,7S)-9-methyl-3-oxa-9-azatricyclo[3.3.1.0²,⁴]nonan-7-yl (2S)-3-hydroxy-2-phenylpropanoate </dd> </dl>

# %%
for r in tab.dt.next_siblings:
    print(r)
# Out:
#
# <a href="/registration-dossier/-/registered-dossier/20490/11/?documentUUID=678a638f-c7c7-4b6a-ae29-b20930206f81"> <dd> Hyoscine </dd> </a>
#
# <dt>EC Number:</dt>
#
# <dd>200-090-3</dd>
#
# <dt>EC Name:</dt>
#
# <dd>Hyoscine</dd>
#
# <dt>CAS Number:</dt>
#
# <dd> 51-34-3 </dd>
#
# <dt>Molecular formula:</dt>
#
# <dd> C17H21NO4 </dd>
#
# <dt>IUPAC Name:</dt>
#
# <dd> (1R,2R,4S,5S,7S)-9-methyl-3-oxa-9-azatricyclo[3.3.1.0²,⁴]nonan-7-yl (2S)-3-hydroxy-2-phenylpropanoate </dd>
